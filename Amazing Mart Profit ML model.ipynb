# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
#numpy aliased as np

import pandas as pd
#pandas aliased as pd

import matplotlib.pyplot as plt
#matplotlib.pyplot aliased as plt

import seaborn as sns
#seaborn aliased as sns

#importing warning module for ignoring warning messages
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading Data using pandas library

# %%
#loading data using pandas library
df = pd.read_csv("Amazing mart.csv")

#Showing Top 5 rows
df.head()
# Out:
#    Unnamed: 0         Order ID Order Date     Customer Name        City  \
# 0           0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm
# 1           1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport
# 2           2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence
# 3           3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham
# 4           4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham
#
#           Country   Region      Segment Ship Date     Ship Mode  \
# 0          Sweden    North  Home Office    1-5-13  Economy Plus
# 1  United Kingdom    North     Consumer    1-7-13       Economy
# 2          France  Central     Consumer    1-8-13       Economy
# 3  United Kingdom    North    Corporate    1-9-13       Economy
# 4  United Kingdom    North    Corporate    1-9-13       Economy
#
#                   State  Days to Ship                           Product Name  \
# 0             Stockholm             4            Enermax Note Cards, Premium
# 1               England             4     Dania Corner Shelving, Traditional
# 2  Auvergne-Rhône-Alpes             4  Binney & Smith Sketch Pad, Easy-Erase
# 3               England             5             Boston Markers, Easy-Erase
# 4               England             5            Eldon Folders, Single Width
#
#    Discount  Actual Discount  Sales  Profit  Quantity         Category  \
# 0       0.5             22.5     45     -26         3  Office Supplies
# 1       0.0              0.0    854     290         7        Furniture
# 2       0.0              0.0    140      21         3  Office Supplies
# 3       0.5             13.5     27     -22         2  Office Supplies
# 4       0.5              8.5     17      -1         2  Office Supplies
#
#   Sub-Category
# 0        Paper
# 1    Bookcases
# 2          Art
# 3          Art
# 4      Storage

# %% [markdown]
# #### Checking data types of Columns

# %%
#Checking data types of columns in dataframe
df.dtypes
# Out:
# Unnamed: 0           int64
# Order ID            object
# Order Date          object
# Customer Name       object
# City                object
# Country             object
# Region              object
# Segment             object
# Ship Date           object
# Ship Mode           object
# State               object
# Days to Ship         int64
# Product Name        object
# Discount           float64
# Actual Discount    float64
# Sales                int64
# Profit               int64
# Quantity             int64
# Category            object
# Sub-Category        object
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
#Checking data types of columns in dataframe
df.dtypes
# Out:
# Unnamed: 0                  int64
# Order ID                   object
# Order Date         datetime64[ns]
# Customer Name              object
# City                       object
# Country                    object
# Region                     object
# Segment                    object
# Ship Date                  object
# Ship Mode                  object
# State                      object
# Days to Ship                int64
# Product Name               object
# Discount                  float64
# Actual Discount           float64
# Sales                       int64
# Profit                      int64
# Quantity                    int64
# Category                   object
# Sub-Category               object
# dtype: object

# %%
df.insert(loc= df.columns.get_loc('Order Date') + 1, column = 'Order Year', value = (df['Order Date'].dt.year) )
df.head()
# Out:
#    Unnamed: 0         Order ID Order Date  Order Year     Customer Name  \
# 0           0  BN-2011-7407039 2013-01-01        2013        Ruby Patel
# 1           1  AZ-2011-9050313 2013-01-03        2013    Summer Hayward
# 2           2  AZ-2011-6674300 2013-01-04        2013  Devin Huddleston
# 3           3  BN-2011-2819714 2013-01-04        2013       Mary Parker
# 4           4  BN-2011-2819714 2013-01-04        2013       Mary Parker
#
#          City         Country   Region      Segment Ship Date  ...  \
# 0   Stockholm          Sweden    North  Home Office    1-5-13  ...
# 1   Southport  United Kingdom    North     Consumer    1-7-13  ...
# 2     Valence          France  Central     Consumer    1-8-13  ...
# 3  Birmingham  United Kingdom    North    Corporate    1-9-13  ...
# 4  Birmingham  United Kingdom    North    Corporate    1-9-13  ...
#
#                   State Days to Ship                           Product Name  \
# 0             Stockholm            4            Enermax Note Cards, Premium
# 1               England            4     Dania Corner Shelving, Traditional
# 2  Auvergne-Rhône-Alpes            4  Binney & Smith Sketch Pad, Easy-Erase
# 3               England            5             Boston Markers, Easy-Erase
# 4               England            5            Eldon Folders, Single Width
#
#   Discount  Actual Discount  Sales  Profit  Quantity         Category  \
# 0      0.5             22.5     45     -26         3  Office Supplies
# 1      0.0              0.0    854     290         7        Furniture
# 2      0.0              0.0    140      21         3  Office Supplies
# 3      0.5             13.5     27     -22         2  Office Supplies
# 4      0.5              8.5     17      -1         2  Office Supplies
#
#   Sub-Category
# 0        Paper
# 1    Bookcases
# 2          Art
# 3          Art
# 4      Storage
#
# [5 rows x 21 columns]

# %%
df.insert(loc= df.columns.get_loc('Product Name') + 1, column = 'Product Sell Price', value = (df['Sales']/df['Quantity']) )
df.head()
# Out:
#    Unnamed: 0         Order ID Order Date  Order Year     Customer Name  \
# 0           0  BN-2011-7407039 2013-01-01        2013        Ruby Patel
# 1           1  AZ-2011-9050313 2013-01-03        2013    Summer Hayward
# 2           2  AZ-2011-6674300 2013-01-04        2013  Devin Huddleston
# 3           3  BN-2011-2819714 2013-01-04        2013       Mary Parker
# 4           4  BN-2011-2819714 2013-01-04        2013       Mary Parker
#
#          City         Country   Region      Segment Ship Date  ...  \
# 0   Stockholm          Sweden    North  Home Office    1-5-13  ...
# 1   Southport  United Kingdom    North     Consumer    1-7-13  ...
# 2     Valence          France  Central     Consumer    1-8-13  ...
# 3  Birmingham  United Kingdom    North    Corporate    1-9-13  ...
# 4  Birmingham  United Kingdom    North    Corporate    1-9-13  ...
#
#   Days to Ship                           Product Name  Product Sell Price  \
# 0            4            Enermax Note Cards, Premium           15.000000
# 1            4     Dania Corner Shelving, Traditional          122.000000
# 2            4  Binney & Smith Sketch Pad, Easy-Erase           46.666667
# 3            5             Boston Markers, Easy-Erase           13.500000
# 4            5            Eldon Folders, Single Width            8.500000
#
#   Discount  Actual Discount  Sales  Profit  Quantity         Category  \
# 0      0.5             22.5     45     -26         3  Office Supplies
# 1      0.0              0.0    854     290         7        Furniture
# 2      0.0              0.0    140      21         3  Office Supplies
# 3      0.5             13.5     27     -22         2  Office Supplies
# 4      0.5              8.5     17      -1         2  Office Supplies
#
#    Sub-Category
# 0         Paper
# 1     Bookcases
# 2           Art
# 3           Art
# 4       Storage
#
# [5 rows x 22 columns]

# %%
df.drop('Unnamed: 0', inplace = True, axis=1)
df.head()
# Out:
#           Order ID Order Date  Order Year     Customer Name        City  \
# 0  BN-2011-7407039 2013-01-01        2013        Ruby Patel   Stockholm
# 1  AZ-2011-9050313 2013-01-03        2013    Summer Hayward   Southport
# 2  AZ-2011-6674300 2013-01-04        2013  Devin Huddleston     Valence
# 3  BN-2011-2819714 2013-01-04        2013       Mary Parker  Birmingham
# 4  BN-2011-2819714 2013-01-04        2013       Mary Parker  Birmingham
#
#           Country   Region      Segment Ship Date     Ship Mode  ...  \
# 0          Sweden    North  Home Office    1-5-13  Economy Plus  ...
# 1  United Kingdom    North     Consumer    1-7-13       Economy  ...
# 2          France  Central     Consumer    1-8-13       Economy  ...
# 3  United Kingdom    North    Corporate    1-9-13       Economy  ...
# 4  United Kingdom    North    Corporate    1-9-13       Economy  ...
#
#   Days to Ship                           Product Name Product Sell Price  \
# 0            4            Enermax Note Cards, Premium          15.000000
# 1            4     Dania Corner Shelving, Traditional         122.000000
# 2            4  Binney & Smith Sketch Pad, Easy-Erase          46.666667
# 3            5             Boston Markers, Easy-Erase          13.500000
# 4            5            Eldon Folders, Single Width           8.500000
#
#    Discount  Actual Discount  Sales  Profit  Quantity         Category  \
# 0       0.5             22.5     45     -26         3  Office Supplies
# 1       0.0              0.0    854     290         7        Furniture
# 2       0.0              0.0    140      21         3  Office Supplies
# 3       0.5             13.5     27     -22         2  Office Supplies
# 4       0.5              8.5     17      -1         2  Office Supplies
#
#   Sub-Category
# 0        Paper
# 1    Bookcases
# 2          Art
# 3          Art
# 4      Storage
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Checking Shape of Data Frame

# %%
#Checking rows and columns count in dataframe
df.shape
# Out:
# (8047, 21)

# %% [markdown]
# **DataFrame has**<br>
# No. of rows = 4340<br>
# No. of Columns = 8

# %% [markdown]
# #### Checking Columns name

# %%
#Checking Columns Name in Dataframe
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Year', 'Customer Name', 'City',
#        'Country', 'Region', 'Segment', 'Ship Date', 'Ship Mode', 'State',
#        'Days to Ship', 'Product Name', 'Product Sell Price', 'Discount',
#        'Actual Discount', 'Sales', 'Profit', 'Quantity', 'Category',
#        'Sub-Category'],
#       dtype='object')

# %%
#Checking counts in each columns
df.count()
# Out:
# Order ID              8047
# Order Date            8047
# Order Year            8047
# Customer Name         8047
# City                  8047
# Country               8047
# Region                8047
# Segment               8047
# Ship Date             8047
# Ship Mode             8047
# State                 8047
# Days to Ship          8047
# Product Name          8047
# Product Sell Price    8047
# Discount              8047
# Actual Discount       8047
# Sales                 8047
# Profit                8047
# Quantity              8047
# Category              8047
# Sub-Category          8047
# dtype: int64

# %% [markdown]
# #### Checking Null Values and there counts in each Column

# %%
#Checking Counts of null values in each column
df.isnull().sum()
# Out:
# Order ID              0
# Order Date            0
# Order Year            0
# Customer Name         0
# City                  0
# Country               0
# Region                0
# Segment               0
# Ship Date             0
# Ship Mode             0
# State                 0
# Days to Ship          0
# Product Name          0
# Product Sell Price    0
# Discount              0
# Actual Discount       0
# Sales                 0
# Profit                0
# Quantity              0
# Category              0
# Sub-Category          0
# dtype: int64

# %% [markdown]
# #### Checking Descriptive statistical Details

# %%
#Checking Descriptive Statistical Details
df.describe(include = 'all').T
# Out:
#                      count unique                            top  freq  \
# Order ID              8047   4117                AZ-2014-7040665    11
# Order Date            8047    NaN                            NaN   NaN
# Order Year          8047.0    NaN                            NaN   NaN
# Customer Name         8047    792                    Joel Peters    32
# City                  8047    999                         London   219
# Country               8047     15                         France  1916
# Region                8047      3                        Central  4426
# Segment               8047      3                       Consumer  4174
# Ship Date             8047   1311                       11-11-16    29
# Ship Mode             8047      4                        Economy  4862
# State                 8047    127                        England  1187
# Days to Ship        8047.0    NaN                            NaN   NaN
# Product Name          8047   1810  Eldon File Cart, Single Width    26
# Product Sell Price  8047.0    NaN                            NaN   NaN
# Discount            8047.0    NaN                            NaN   NaN
# Actual Discount     8047.0    NaN                            NaN   NaN
# Sales               8047.0    NaN                            NaN   NaN
# Profit              8047.0    NaN                            NaN   NaN
# Quantity            8047.0    NaN                            NaN   NaN
# Category              8047      3                Office Supplies  5286
# Sub-Category          8047     17                            Art  1152
#
#                                              mean                  min  \
# Order ID                                      NaN                  NaN
# Order Date          2015-04-20 12:25:40.748104704  2013-01-01 00:00:00
# Order Year                             2014.73108               2013.0
# Customer Name                                 NaN                  NaN
# City                                          NaN                  NaN
# Country                                       NaN                  NaN
# Region                                        NaN                  NaN
# Segment                                       NaN                  NaN
# Ship Date                                     NaN                  NaN
# Ship Mode                                     NaN                  NaN
# State                                         NaN                  NaN
# Days to Ship                             4.007332                  0.0
# Product Name                                  NaN                  NaN
# Product Sell Price                      77.688136             2.111111
# Discount                                 0.110047                  0.0
# Actual Discount                         29.793078                  0.0
# Sales                                  291.845657                  3.0
# Profit                                  35.198211              -3060.0
# Quantity                                 3.772089                  1.0
# Category                                      NaN                  NaN
# Sub-Category                                  NaN                  NaN
#
#                                     25%                  50%  \
# Order ID                            NaN                  NaN
# Order Date          2014-06-09 00:00:00  2015-06-12 00:00:00
# Order Year                       2014.0               2015.0
# Customer Name                       NaN                  NaN
# City                                NaN                  NaN
# Country                             NaN                  NaN
# Region                              NaN                  NaN
# Segment                             NaN                  NaN
# Ship Date                           NaN                  NaN
# Ship Mode                           NaN                  NaN
# State                               NaN                  NaN
# Days to Ship                        3.0                  4.0
# Product Name                        NaN                  NaN
# Product Sell Price            15.633333                 36.6
# Discount                            0.0                  0.0
# Actual Discount                     0.0                  0.0
# Sales                              48.0                117.0
# Profit                              1.0                 14.0
# Quantity                            2.0                  3.0
# Category                            NaN                  NaN
# Sub-Category                        NaN                  NaN
#
#                                     75%                  max         std
# Order ID                            NaN                  NaN         NaN
# Order Date          2016-04-30 00:00:00  2016-12-31 00:00:00         NaN
# Order Year                       2016.0               2016.0    1.100474
# Customer Name                       NaN                  NaN         NaN
# City                                NaN                  NaN         NaN
# Country                             NaN                  NaN         NaN
# Region                              NaN                  NaN         NaN
# Segment                             NaN                  NaN         NaN
# Ship Date                           NaN                  NaN         NaN
# Ship Mode                           NaN                  NaN         NaN
# State                               NaN                  NaN         NaN
# Days to Ship                        5.0                  7.0    1.741232
# Product Name                        NaN                  NaN         NaN
# Product Sell Price                 91.0                873.0  105.784205
# Discount                            0.1                 0.85    0.181773
# Actual Discount                    22.0               1700.0   88.817656
# Sales                             313.0               6517.0  485.212156
# Profit                             47.0               2476.0  178.125844
# Quantity                            5.0                 14.0    2.203369
# Category                            NaN                  NaN         NaN
# Sub-Category                        NaN                  NaN         NaN

# %%
#Checking null values and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            8047 non-null   object
#  1   Order Date          8047 non-null   datetime64[ns]
#  2   Order Year          8047 non-null   int32
#  3   Customer Name       8047 non-null   object
#  4   City                8047 non-null   object
#  5   Country             8047 non-null   object
#  6   Region              8047 non-null   object
#  7   Segment             8047 non-null   object
#  8   Ship Date           8047 non-null   object
#  9   Ship Mode           8047 non-null   object
#  10  State               8047 non-null   object
#  11  Days to Ship        8047 non-null   int64
#  12  Product Name        8047 non-null   object
#  13  Product Sell Price  8047 non-null   float64
#  14  Discount            8047 non-null   float64
#  15  Actual Discount     8047 non-null   float64
#  16  Sales               8047 non-null   int64
#  17  Profit              8047 non-null   int64
#  18  Quantity            8047 non-null   int64
#  19  Category            8047 non-null   object
#  20  Sub-Category        8047 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(12)
# memory usage: 1.3+ MB

# %%
#Checking Duplicates entry
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (8045, 21)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Year', 'Customer Name', 'City',
#        'Country', 'Region', 'Segment', 'Ship Date', 'Ship Mode', 'State',
#        'Days to Ship', 'Product Name', 'Product Sell Price', 'Discount',
#        'Actual Discount', 'Sales', 'Profit', 'Quantity', 'Category',
#        'Sub-Category'],
#       dtype='object')

# %%
df1 = df[['Region','Country','State','Segment','Category','Sub-Category','Product Name','Product Sell Price','Quantity','Sales','Discount','Actual Discount','Profit']]
df1.head()
# Out:
#     Region         Country                 State      Segment  \
# 0    North          Sweden             Stockholm  Home Office
# 1    North  United Kingdom               England     Consumer
# 2  Central          France  Auvergne-Rhône-Alpes     Consumer
# 3    North  United Kingdom               England    Corporate
# 4    North  United Kingdom               England    Corporate
#
#           Category Sub-Category                           Product Name  \
# 0  Office Supplies        Paper            Enermax Note Cards, Premium
# 1        Furniture    Bookcases     Dania Corner Shelving, Traditional
# 2  Office Supplies          Art  Binney & Smith Sketch Pad, Easy-Erase
# 3  Office Supplies          Art             Boston Markers, Easy-Erase
# 4  Office Supplies      Storage            Eldon Folders, Single Width
#
#    Product Sell Price  Quantity  Sales  Discount  Actual Discount  Profit
# 0           15.000000         3     45       0.5             22.5     -26
# 1          122.000000         7    854       0.0              0.0     290
# 2           46.666667         3    140       0.0              0.0      21
# 3           13.500000         2     27       0.5             13.5     -22
# 4            8.500000         2     17       0.5              8.5      -1

# %%
df1.shape
# Out:
# (8045, 13)

# %%
df1.describe().round()
# Out:
#        Product Sell Price  Quantity   Sales  Discount  Actual Discount  Profit
# count              8045.0    8045.0  8045.0    8045.0           8045.0  8045.0
# mean                 78.0       4.0   292.0       0.0             30.0    35.0
# std                 106.0       2.0   485.0       0.0             89.0   178.0
# min                   2.0       1.0     3.0       0.0              0.0 -3060.0
# 25%                  16.0       2.0    48.0       0.0              0.0     1.0
# 50%                  37.0       3.0   117.0       0.0              0.0    14.0
# 75%                  91.0       5.0   313.0       0.0             22.0    47.0
# max                 873.0      14.0  6517.0       1.0           1700.0  2476.0

# %%
for i in df1.select_dtypes(include = ['object']):
    print('No. of Unique values in column',i,'is:',df[i].nunique())
    print('\n')
    print(df[i].unique())
    print('\n')
    print('*-'*50,'\n')
# Out:
# No. of Unique values in column Region is: 3
#
#
# ['North' 'Central' 'South']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column Country is: 15
#
#
# ['Sweden' 'United Kingdom' 'France' 'Italy' 'Austria' 'Spain' 'Germany'
#  'Netherlands' 'Denmark' 'Belgium' 'Norway' 'Portugal' 'Switzerland'
#  'Ireland' 'Finland']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column State is: 127
#
#
# ['Stockholm' 'England' 'Auvergne-Rhône-Alpes' "Provence-Alpes-Côte d'Azur"
#  'Languedoc-Roussillon-Midi-Pyrénées' 'Liguria' 'Vienna' 'Murcia'
#  'Lower Saxony' 'South Holland' 'Västra Götaland' 'Hovedstaden'
#  'Valenciana' 'South Denmark' 'Lombardy' 'Sicily' 'Ile-de-France'
#  'North Rhine-Westphalia' 'Flemish Brabant' 'Tuscany' 'Emilia-Romagna'
#  'Madrid' 'Oslo' 'Lisboa' 'Saxony' 'Andalusía' 'Catalonia'
#  'Alsace-Champagne-Ardenne-Lorraine' 'Bavaria' 'Uppsala'
#  'Nord-Pas-de-Calais-Picardie' 'Hesse' 'Overijssel' 'Basel-Stadt'
#  'Bourgogne-Franche-Comté' 'Zürich' 'Dublin' 'Lazio' 'Namur'
#  'North Holland' 'Berlin' 'Baden-Württemberg'
#  'Aquitaine-Limousin-Poitou-Charentes' 'Uusimaa' 'Apulia' 'Saxony-Anhalt'
#  'Rogaland' 'Sardinia' 'Drenthe' 'Mecklenburg-Vorpommern' 'North Brabant'
#  'Umbria' 'Geneva' 'Veneto' 'Normandy' 'Scotland' 'Coimbra'
#  'Castile and León' 'Gelderland' 'Hamburg' 'Brandenburg'
#  'Pays de la Loire' 'Antwerp' 'Bremen' 'Thuringia' 'Porto' 'Utrecht'
#  'Castile-La Mancha' 'Brittany' 'Campania' 'Cork' 'Groningen'
#  'East Flanders' 'Ceuta' 'Halland' 'Navarra' 'Rhineland-Palatinate'
#  'Limburg' 'Upper Austria' 'Schleswig-Holstein' 'Tyrol' 'Corsica'
#  'Trentino-Alto Adige' 'Vaud' 'Piedmont' 'Calabria' 'Galicia' 'Buskerud'
#  'Centre-Val de Loire' 'Styria' 'Abruzzi' 'Basque Country' 'Cantabria'
#  'Asturias' 'Finland Proper' 'Central Jutland' 'Wales' 'Kymenlaakso'
#  'Friesland' 'Braga' 'Aveiro' 'Marche' 'Saarland' 'Skåne'
#  'Friuli-Venezia Giulia' 'Balearic Islands' 'Extremadura' 'Basilicata'
#  'Hedmark' 'Hainaut' 'Melilla' 'Salzburg' 'Carinthia' 'Zeeland'
#  'Hordaland' 'Lucerne' 'Liège' 'West Flanders' 'Bern' 'Brussels'
#  'Södermanland' 'Zealand' 'Galway' 'Värmland' 'Vest-Agder' 'St. Gallen'
#  'Setúbal']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column Segment is: 3
#
#
# ['Home Office' 'Consumer' 'Corporate']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column Category is: 3
#
#
# ['Office Supplies' 'Furniture' 'Technology']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column Sub-Category is: 17
#
#
# ['Paper' 'Bookcases' 'Art' 'Storage' 'Fasteners' 'Binders' 'Tables'
#  'Labels' 'Chairs' 'Machines' 'Phones' 'Appliances' 'Supplies' 'Copiers'
#  'Envelopes' 'Accessories' 'Furnishings']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# No. of Unique values in column Product Name is: 1810
#
#
# ['Enermax Note Cards, Premium' 'Dania Corner Shelving, Traditional'
#  'Binney & Smith Sketch Pad, Easy-Erase' ...
#  'HP Fax and Copier, High-Speed' 'Eldon Stacking Tray, Erganomic'
#  'Panasonic Card Printer, Red']
#
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df1, x='Sub-Category', y='Product Sell Price')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df1, x='Sub-Category', y='Quantity')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df1, x='Sub-Category', y='Sales')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df1, x='Sub-Category', y='Discount')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df1, x='Sub-Category', y='Profit')
plt.xticks(rotation = 45)
plt.show()

# %%
# plt.figure(figsize = (24,48))
for i in df1.select_dtypes(include = ['int64','float64']):
    sns.boxplot(x= df1[i])
    plt.title([i], size = 10)
    plt.show()

# %%
df1.head()
# Out:
#     Region         Country                 State      Segment  \
# 0    North          Sweden             Stockholm  Home Office
# 1    North  United Kingdom               England     Consumer
# 2  Central          France  Auvergne-Rhône-Alpes     Consumer
# 3    North  United Kingdom               England    Corporate
# 4    North  United Kingdom               England    Corporate
#
#           Category Sub-Category                           Product Name  \
# 0  Office Supplies        Paper            Enermax Note Cards, Premium
# 1        Furniture    Bookcases     Dania Corner Shelving, Traditional
# 2  Office Supplies          Art  Binney & Smith Sketch Pad, Easy-Erase
# 3  Office Supplies          Art             Boston Markers, Easy-Erase
# 4  Office Supplies      Storage            Eldon Folders, Single Width
#
#    Product Sell Price  Quantity  Sales  Discount  Actual Discount  Profit
# 0           15.000000         3     45       0.5             22.5     -26
# 1          122.000000         7    854       0.0              0.0     290
# 2           46.666667         3    140       0.0              0.0      21
# 3           13.500000         2     27       0.5             13.5     -22
# 4            8.500000         2     17       0.5              8.5      -1

# %%
import pickle

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder for each column
LBE = {}

for col in df1.select_dtypes('object'):
    LBE[col] = LabelEncoder()
    df1[col] = LBE[col].fit_transform(df1[col])
    
    pickle.dump(LBE[col], open(f"{col}_LBE.pkl" , 'wb'))

# %%
# from sklearn.preprocessing import LabelEncoder

# for i in df1.select_dtypes('object'):
#     labe = LabelEncoder()
#     df1[i]= labe.fit_transform(df1[i])

# df1.head()

# %%
df1.head()
# Out:
#    Region  Country  State  Segment  Category  Sub-Category  Product Name  \
# 0       1       12    103        2         1            12           670
# 1       1       14     41        0         0             4           513
# 2       0        4      7        0         1             2           294
# 3       1       14     41        1         1             2           306
# 4       1       14     41        1         1            14           585
#
#    Product Sell Price  Quantity  Sales  Discount  Actual Discount  Profit
# 0           15.000000         3     45       0.5             22.5     -26
# 1          122.000000         7    854       0.0              0.0     290
# 2           46.666667         3    140       0.0              0.0      21
# 3           13.500000         2     27       0.5             13.5     -22
# 4            8.500000         2     17       0.5              8.5      -1

# %%
df1.describe().T
# Out:
#                      count        mean         std          min         25%  \
# Region              8045.0    0.674829    0.818070     0.000000    0.000000
# Country             8045.0    7.264512    4.010136     0.000000    4.000000
# State               8045.0   59.279925   32.574799     0.000000   41.000000
# Segment             8045.0    0.650093    0.751760     0.000000    0.000000
# Category            8045.0    1.035426    0.584792     0.000000    1.000000
# Sub-Category        8045.0    7.335736    4.895225     0.000000    3.000000
# Product Name        8045.0  897.813300  556.217467     0.000000  382.000000
# Product Sell Price  8045.0   77.702436  105.793393     2.111111   15.666667
# Quantity            8045.0    3.772281    2.203610     1.000000    2.000000
# Sales               8045.0  291.903170  485.258616     3.000000   48.000000
# Discount            8045.0    0.110075    0.181787     0.000000    0.000000
# Actual Discount     8045.0   29.800485   88.827454     0.000000    0.000000
# Profit              8045.0   35.202237  178.147747 -3060.000000    1.000000
#
#                       50%     75%      max
# Region                0.0     1.0     2.00
# Country               5.0    11.0    14.00
# State                59.0    81.0   126.00
# Segment               0.0     1.0     2.00
# Category              1.0     1.0     2.00
# Sub-Category          7.0    12.0    16.00
# Product Name        875.0  1408.0  1809.00
# Product Sell Price   36.6    91.0   873.00
# Quantity              3.0     5.0    14.00
# Sales               117.0   313.0  6517.00
# Discount              0.0     0.1     0.85
# Actual Discount       0.0    22.0  1700.00
# Profit               14.0    47.0  2476.00

# %%
df1.shape
# Out:
# (8045, 13)

# %%
corr = df1.corr()
corr.head()
# Out:
#             Region   Country     State   Segment  Category  Sub-Category  \
# Region    1.000000  0.559362 -0.030993 -0.002093  0.004593      0.006838
# Country   0.559362  1.000000 -0.115153  0.001798  0.002259      0.001017
# State    -0.030993 -0.115153  1.000000 -0.002777 -0.003359      0.003532
# Segment  -0.002093  0.001798 -0.002777  1.000000 -0.002623      0.012942
# Category  0.004593  0.002259 -0.003359 -0.002623  1.000000      0.065370
#
#           Product Name  Product Sell Price  Quantity     Sales  Discount  \
# Region       -0.015201           -0.012742 -0.013772 -0.010782  0.038374
# Country      -0.008637           -0.004760 -0.001736  0.001569  0.085515
# State         0.011371           -0.031858 -0.013318 -0.035877  0.127647
# Segment       0.003113           -0.016085  0.003225 -0.013822 -0.018093
# Category     -0.004983            0.078870  0.009155  0.071851 -0.036978
#
#           Actual Discount    Profit
# Region          -0.019684 -0.009724
# Country         -0.029018  0.011578
# State            0.014386 -0.053568
# Segment         -0.003589 -0.004838
# Category        -0.026734  0.058217

# %% [markdown]
# #### Select the Dependent and Independent Features

# %%
corr[corr<0]
# Out:
#                       Region   Country     State   Segment  Category  \
# Region                   NaN       NaN -0.030993 -0.002093       NaN
# Country                  NaN       NaN -0.115153       NaN       NaN
# State              -0.030993 -0.115153       NaN -0.002777 -0.003359
# Segment            -0.002093       NaN -0.002777       NaN -0.002623
# Category                 NaN       NaN -0.003359 -0.002623       NaN
# Sub-Category             NaN       NaN       NaN       NaN       NaN
# Product Name       -0.015201 -0.008637       NaN       NaN -0.004983
# Product Sell Price -0.012742 -0.004760 -0.031858 -0.016085       NaN
# Quantity           -0.013772 -0.001736 -0.013318       NaN       NaN
# Sales              -0.010782       NaN -0.035877 -0.013822       NaN
# Discount                 NaN       NaN       NaN -0.018093 -0.036978
# Actual Discount    -0.019684 -0.029018       NaN -0.003589 -0.026734
# Profit             -0.009724       NaN -0.053568 -0.004838       NaN
#
#                     Sub-Category  Product Name  Product Sell Price  Quantity  \
# Region                       NaN     -0.015201           -0.012742 -0.013772
# Country                      NaN     -0.008637           -0.004760 -0.001736
# State                        NaN           NaN           -0.031858 -0.013318
# Segment                      NaN           NaN           -0.016085       NaN
# Category                     NaN     -0.004983                 NaN       NaN
# Sub-Category                 NaN           NaN                 NaN -0.004874
# Product Name                 NaN           NaN                 NaN       NaN
# Product Sell Price           NaN           NaN                 NaN -0.005201
# Quantity               -0.004874           NaN           -0.005201       NaN
# Sales                        NaN           NaN                 NaN       NaN
# Discount                     NaN           NaN           -0.038480       NaN
# Actual Discount              NaN           NaN                 NaN       NaN
# Profit                 -0.083605           NaN                 NaN       NaN
#
#                        Sales  Discount  Actual Discount    Profit
# Region             -0.010782       NaN        -0.019684 -0.009724
# Country                  NaN       NaN        -0.029018       NaN
# State              -0.035877       NaN              NaN -0.053568
# Segment            -0.013822 -0.018093        -0.003589 -0.004838
# Category                 NaN -0.036978        -0.026734       NaN
# Sub-Category             NaN       NaN              NaN -0.083605
# Product Name             NaN       NaN              NaN       NaN
# Product Sell Price       NaN -0.038480              NaN       NaN
# Quantity                 NaN       NaN              NaN       NaN
# Sales                    NaN -0.026424              NaN       NaN
# Discount           -0.026424       NaN              NaN -0.351359
# Actual Discount          NaN       NaN              NaN -0.395889
# Profit                   NaN -0.351359        -0.395889       NaN

# %%
df_unscaled = df1.drop('Profit',axis=1)  # dataframe
y = df1['Profit']              # series
print(type(df_unscaled))
print(type(y))
print(df_unscaled.shape,y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (8045, 12) (8045,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df_unscaled)
x = scaler.transform(df_unscaled)

# %%
x = pd.DataFrame(x ,columns=df_unscaled.columns,index=df_unscaled.index)
x.head()
# Out:
#      Region   Country     State   Segment  Category  Sub-Category  \
# 0  0.397510  1.180953  1.342228  1.795773 -0.060582      0.952878
# 1  0.397510  1.679720 -0.561203 -0.864815 -1.770697     -0.681469
# 2 -0.824955 -0.814116 -1.605019 -0.864815 -0.060582     -1.090056
# 3  0.397510  1.679720 -0.561203  0.465479 -0.060582     -1.090056
# 4  0.397510  1.679720 -0.561203  0.465479 -0.060582      1.361465
#
#    Product Name  Product Sell Price  Quantity     Sales  Discount  \
# 0     -0.409601           -0.592724 -0.350484 -0.508839  2.145092
# 1     -0.691883            0.418744  1.464833  1.158417 -0.605552
# 2     -1.085638           -0.293380 -0.350484 -0.313055 -0.605552
# 3     -1.064062           -0.606904 -0.804313 -0.545935  2.145092
# 4     -0.562429           -0.654169 -0.804313 -0.566544  2.145092
#
#    Actual Discount
# 0        -0.082192
# 1        -0.335508
# 2        -0.335508
# 3        -0.183519
# 4        -0.239811

# %% [markdown]
# #### Dividing the data into training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6033, 12)
# (2012, 12)
# (6033,)
# (2012,)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
d = {'Model':[],'MAE':[],'MSE':[],'RMSE':[],'R2_SCORE':[],'Train_Score':[],'Test_Score':[]}

def eval_model(model,model_name,x_train,y_train,x_test,y_test,y_pred):
    mae = mean_absolute_error(y_test,y_pred)
    mse = mean_squared_error(y_test,y_pred)
    rmse =np.sqrt(mean_squared_error(y_test,y_pred))
    r2s = r2_score(y_test, y_pred)
    Train_Score = model.score(x_train, y_train)
    Test_Score = model.score(x_test, y_test)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2_Score:', r2s)
    print('Training Score',model.score(x_train,y_train))  # Training dataset Accuracy
    print('Testing Score',model.score(x_test,y_test))     # Testing dataset accuracy
    d['Model'].append(model_name)
    d['MAE'].append(mae)
    d['MSE'].append(mse)
    d['RMSE'].append(rmse)
    d['R2_SCORE'].append(r2s)
    d['Train_Score'].append(Train_Score)
    d['Test_Score'].append(Test_Score)
    

    
def mscore(model):
    print('Training Score',model.score(x_train,y_train))  # Training dataset Accuracy
    print('Testing Score',model.score(x_test,y_test))     # Testing dataset accuracy

# %%
def reg_eval_metrics(y_test, y_pred):
    mae = mean_absolute_error(y_test,y_pred)
    mse = mean_squared_error(y_test,y_pred)
    rmse =np.sqrt(mean_squared_error(y_test,y_pred))
    r2s = r2_score(y_test, y_pred)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2_Score:', r2s)

def train_test_score(model):
    print('Training_Score:', model.score(x_train, y_train))
    print('Testing_Score:', model.score(x_test, y_test))

# %%
m0 = LinearRegression()
m0.fit(x_train,y_train)
y_pred0 = m0.predict(x_test)
print(y_pred0)
train_test_score(m0)
# Out:
# [   74.47856932   425.58578293    27.5095334  ...     2.27893966
#  -1580.44471602     1.6910745 ]
# Training_Score: 0.6719700764888752
# Testing_Score: 0.6774306669561083

# %%
eval_model(m0, 'LinearRegression',x_train, y_train,x_test,y_test, y_pred0)
# Out:
# MAE: 49.41807922193409
# MSE: 14062.347514637051
# RMSE: 118.58476931982898
# R2_Score: 0.6774306669561083
# Training Score 0.6719700764888752
# Testing Score 0.6774306669561083

# %%
# Importing KFold from sklearn.model_selection
from sklearn.model_selection import KFold
# Importing cross_val_score from sklearn.model_selection
from sklearn.model_selection import cross_val_score

# %%
# Initializing LinearRegression()
regressor = LinearRegression()
# Initializing KFold () and setting n_splits=5, random_state=2022 and shuffle=True
kfold = KFold(n_splits=13, random_state=1,shuffle=True)
# Applying the regressor and calculating result using cross_val_score() method and setting  cv=kfold, scoring='r2'
results = cross_val_score(regressor, x, y, cv=kfold, scoring='r2')
# Assigning a variable R2 to the result 
R2 = results

# %%
print(R2)
print("R-Squared: %.2f" % (R2.mean()))
# Out:
# [0.55687541 0.60849267 0.70458833 0.62825754 0.62043445 0.72886957
#  0.60818162 0.73661381 0.7098049  0.60052796 0.76640894 0.62431951
#  0.60061154]
# R-Squared: 0.65

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
m1 = KNeighborsRegressor(n_neighbors = 7)
m1.fit(x_train,y_train)
y_pred1 = m1.predict(x_test)
print(y_pred1)
train_test_score(m1)
# Out:
# [   55.57142857   237.42857143    15.42857143 ...     3.71428571
#  -1041.85714286    22.        ]
# Training_Score: 0.717961744944388
# Testing_Score: 0.5922219021677984

# %%
eval_model(m1, 'KNeighborsRegressor',x_train, y_train,x_test,y_test, y_pred1)
# Out:
# MAE: 54.038554387957966
# MSE: 17777.007090112384
# RMSE: 133.33044322326535
# R2_Score: 0.5922219021677984
# Training Score 0.717961744944388
# Testing Score 0.5922219021677984

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
m2 = Ridge(alpha=0)
m2.fit(x_train, y_train)
y_pred2 = m2.predict(x_test)
print(y_pred2)
train_test_score(m2)
# Out:
# [   74.47856932   425.58578293    27.5095334  ...     2.27893966
#  -1580.44471602     1.6910745 ]
# Training_Score: 0.6719700764888752
# Testing_Score: 0.6774306669561084

# %%
eval_model(m2, 'Ridge',x_train, y_train,x_test,y_test, y_pred2)
# Out:
# MAE: 49.41807922193409
# MSE: 14062.347514637044
# RMSE: 118.58476931982894
# R2_Score: 0.6774306669561084
# Training Score 0.6719700764888752
# Testing Score 0.6774306669561084

# %%
m3 = Lasso(alpha=0)
m3.fit(x_train, y_train)
y_pred3 = m3.predict(x_test)
print(y_pred3)
train_test_score(m3)
# Out:
# [   74.47856932   425.58578293    27.5095334  ...     2.27893966
#  -1580.44471602     1.6910745 ]
# Training_Score: 0.6719700764888752
# Testing_Score: 0.6774306669561083

# %%
eval_model(m3, 'Lasso',x_train, y_train,x_test,y_test, y_pred3)
# Out:
# MAE: 49.418079221934086
# MSE: 14062.347514637047
# RMSE: 118.58476931982896
# R2_Score: 0.6774306669561083
# Training Score 0.6719700764888752
# Testing Score 0.6774306669561083

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
m4 = DecisionTreeRegressor(max_depth= 5, min_samples_split= 20,random_state= 42)
m4.fit(x_train, y_train)
y_pred4 = m4.predict(x_test)
print(y_pred4)
train_test_score(m4)
# Out:
# [  76.17102804  376.58571429   19.18711276 ...   19.18711276 -781.45454545
#    76.17102804]
# Training_Score: 0.6966004835059584
# Testing_Score: 0.5576502405929684

# %%
eval_model(m4, 'DecisionTreeRegressor',x_train, y_train,x_test,y_test, y_pred4)
# Out:
# MAE: 55.50803814248493
# MSE: 19284.15197160529
# RMSE: 138.86738987827664
# R2_Score: 0.5576502405929684
# Training Score 0.6966004835059584
# Testing Score 0.5576502405929684

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
m5 = RandomForestRegressor(n_estimators= 100, random_state= 42)
m5.fit(x_train, y_train)
y_pred5 = m5.predict(x_test)
print(y_pred5)
train_test_score(m5)
# Out:
# [  38.81  253.99   17.88 ...    2.78 -805.34   21.53]
# Training_Score: 0.9460166586057279
# Testing_Score: 0.6254982177327418

# %%
eval_model(m5, 'RandomForestRegressor',x_train, y_train,x_test,y_test, y_pred5)
# Out:
# MAE: 47.989850894632205
# MSE: 16326.332566699803
# RMSE: 127.77453802186022
# R2_Score: 0.6254982177327418
# Training Score 0.9460166586057279
# Testing Score 0.6254982177327418

# %%
from sklearn.ensemble import BaggingRegressor

# %%
m6 = BaggingRegressor(estimator=RandomForestRegressor(),n_estimators= 1 ,random_state= 1)
m6.fit(x_train, y_train)
y_pred6 = m6.predict(x_test)
print(y_pred6)
train_test_score(m6)
# Out:
# [   32.02   275.96    17.81 ...     2.42 -1101.06    17.5 ]
# Training_Score: 0.8038894756896486
# Testing_Score: 0.6605234129241915

# %%
eval_model(m6, 'BaggingRegressor',x_train, y_train,x_test,y_test, y_pred6)
# Out:
# MAE: 47.23054671968191
# MSE: 14799.415975149106
# RMSE: 121.65285025493282
# R2_Score: 0.6605234129241915
# Training Score 0.8038894756896486
# Testing Score 0.6605234129241915

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
m7 = AdaBoostRegressor(estimator= RandomForestRegressor(),n_estimators=63,random_state=1)
m7.fit(x_train, y_train)
y_pred7 = m7.predict(x_test)
print(y_pred7)
train_test_score(m7)
# Out:
# [   52.84   283.72    15.82 ...     7.06 -1268.16     7.9 ]
# Training_Score: 0.9957066778648607
# Testing_Score: 0.6672843874736691

# %%
eval_model(m7, 'AdaBoostRegressor',x_train, y_train,x_test,y_test, y_pred7)
# Out:
# MAE: 47.012743538767396
# MSE: 14504.672600894633
# RMSE: 120.43534614428869
# R2_Score: 0.6672843874736691
# Training Score 0.9957066778648607
# Testing Score 0.6672843874736691

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
m8 = GradientBoostingRegressor(n_estimators= 50000,random_state=1)
m8.fit(x_train, y_train)
y_pred8 = m8.predict(x_test)
print(y_pred8)
train_test_score(m8)
# Out:
# [   28.12821615   103.08725273    23.43943842 ...     4.55838573
#  -1447.73215649   -26.07282006]
# Training_Score: 0.9999994597411452
# Testing_Score: 0.7334204845362217

# %%
eval_model(m8, 'GradientBoostRegressor',x_train, y_train,x_test,y_test, y_pred8)
# Out:
# MAE: 36.599013372060725
# MSE: 11621.4822759519
# RMSE: 107.80297897531356
# R2_Score: 0.7334204845362217
# Training Score 0.9999994597411452
# Testing Score 0.7334204845362217

# %%
model_performance = pd.DataFrame(d)
model_performance.round(2)
# Out:
#                     Model    MAE       MSE    RMSE  R2_SCORE  Train_Score  \
# 0        LinearRegression  49.42  14062.35  118.58      0.68         0.67
# 1     KNeighborsRegressor  54.04  17777.01  133.33      0.59         0.72
# 2                   Ridge  49.42  14062.35  118.58      0.68         0.67
# 3                   Lasso  49.42  14062.35  118.58      0.68         0.67
# 4   DecisionTreeRegressor  55.51  19284.15  138.87      0.56         0.70
# 5   RandomForestRegressor  47.99  16326.33  127.77      0.63         0.95
# 6        BaggingRegressor  47.23  14799.42  121.65      0.66         0.80
# 7       AdaBoostRegressor  47.01  14504.67  120.44      0.67         1.00
# 8  GradientBoostRegressor  36.60  11621.48  107.80      0.73         1.00
#
#    Test_Score
# 0        0.68
# 1        0.59
# 2        0.68
# 3        0.68
# 4        0.56
# 5        0.63
# 6        0.66
# 7        0.67
# 8        0.73

# %%
sample_df = x.sample(20,random_state=1)
print(x.shape)
print(sample_df.shape)
sample_df
# Out:
# (8045, 12)
# (20, 12)
#         Region   Country     State   Segment  Category  Sub-Category  \
# 573  -0.824955 -0.814116  0.851020  0.465479  1.649533      0.748585
# 6197 -0.824955 -0.814116  0.544015 -0.864815 -1.770697      0.339998
# 103  -0.824955  1.430337 -1.482217  0.465479 -1.770697     -0.681469
# 3947 -0.824955 -0.564732  0.666817 -0.864815 -0.060582     -0.068589
# 3360  1.619976 -0.065965  0.789619  1.795773 -0.060582     -1.294349
# 4733 -0.824955 -0.814116 -0.008594  1.795773 -0.060582      0.135705
# 5736  0.397510  1.679720 -0.561203 -0.864815  1.649533      0.748585
# 3351 -0.824955 -0.564732 -0.100695 -0.864815 -1.770697     -0.477176
# 2919  0.397510  1.679720 -0.561203 -0.864815 -0.060582     -1.090056
# 7388 -0.824955 -0.564732  0.666817  0.465479  1.649533      0.748585
# 4003 -0.824955 -0.814116  0.851020 -0.864815 -1.770697      1.770052
# 7903  1.619976 -0.065965  1.188725 -0.864815  1.649533      1.157172
# 4910  1.619976  0.931569  0.329111 -0.864815 -0.060582      1.361465
# 1651 -0.824955 -0.814116 -0.008594 -0.864815 -0.060582      0.952878
# 4121  0.397510  1.679720  1.127324 -0.864815 -0.060582     -0.885762
# 4502 -0.824955 -0.814116  0.851020  0.465479 -0.060582      0.135705
# 4879 -0.824955 -0.814116 -0.008594  0.465479  1.649533      1.157172
# 4577 -0.824955 -0.814116  0.544015  1.795773 -0.060582     -1.090056
# 5092 -0.824955 -0.564732 -0.162096 -0.864815 -0.060582      0.135705
# 1827 -0.824955 -1.562266  0.144909 -0.864815 -0.060582      1.565759
#
#       Product Name  Product Sell Price  Quantity     Sales  Discount  \
# 573       0.363526            1.416032 -0.804313  0.336124  0.219641
# 6197     -0.573217           -0.274024  1.464833  0.101183 -0.605552
# 103       1.186996            2.952141 -0.804313  1.005911 -0.605552
# 3947     -1.384101           -0.570668 -0.350484 -0.494413 -0.605552
# 3360     -1.017315            4.157395  0.103346  3.664453 -0.605552
# 4733     -1.441636           -0.583271  0.557175 -0.436708 -0.605552
# 5736      0.777059            0.536906 -0.804313 -0.047201  2.145092
# 3351     -0.105745           -0.230811  1.464833  0.167131 -0.055423
# 2919     -1.225880           -0.446203 -0.804313 -0.475865 -0.605552
# 7388     -0.355662            0.356870  3.280149  2.015745 -0.605552
# 4003     -1.128789            1.337573  0.557175  1.657151  1.319899
# 7903      1.016189            0.056380 -0.350484 -0.084297  1.594963
# 4910      1.505236           -0.536007 -0.350484 -0.471743 -0.055423
# 1651      1.631094           -0.484961  0.557175 -0.329542 -0.605552
# 4121     -0.806953           -0.670712  0.103346 -0.545935 -0.605552
# 4502      1.472873           -0.609740  0.557175 -0.465560 -0.605552
# 4879      0.586474            4.398446 -0.804313  1.636542  0.219641
# 4577     -1.114406           -0.578545 -0.804313 -0.533570 -0.605552
# 5092      0.701544           -0.649442 -0.804313 -0.564483 -0.605552
# 1827     -1.493777           -0.318588  1.464833  0.033174 -0.605552
#
#       Actual Discount
# 573          0.432883
# 6197        -0.335508
# 103         -0.335508
# 3947        -0.335508
# 3360        -0.335508
# 4733        -0.335508
# 5736         1.178757
# 3351         0.084433
# 2919        -0.335508
# 7388        -0.335508
# 4003         3.983245
# 7903         0.794843
# 4910        -0.264580
# 1651        -0.335508
# 4121        -0.335508
# 4502        -0.335508
# 4879         1.498498
# 4577        -0.335508
# 5092        -0.335508
# 1827        -0.335508

# %%
sample_df.to_csv('Sample_data_Model_Testing.csv',index=False)

# %%
test_model1 = GradientBoostingRegressor(n_estimators= 50000, random_state=1)
test_model1.fit(x,y)
# Out:
# GradientBoostingRegressor(n_estimators=50000, random_state=1)

# %%
ypred_test1 = test_model1.predict(sample_df)
ypred_test1
# Out:
# array([ -64.1218253 ,   44.82613319,  117.02980926,   17.52773403,
#         414.05656479,   22.2267593 ,  -86.1023033 ,   -4.01473031,
#          21.29572257,  545.94376219, -421.96251913,    3.86585725,
#           8.10017565,   26.00993249,   10.71184995,   16.17966182,
#         268.03410927,    4.98366129,    7.34048309,   67.99936181])

# %%
train_test_score(test_model1)
# Out:
# Training_Score: 0.9999972567795469
# Testing_Score: 0.9999982090488312

# %%
test_model2 = LinearRegression()
test_model2.fit(x,y)
# Out:
# LinearRegression()

# %%
ypred_test2 = test_model2.predict(sample_df)
ypred_test2
# Out:
# array([  22.1903641 ,   96.58658874,  243.33291002,   12.04823549,
#         621.14351198,   19.41974902, -139.65592718,   49.00825276,
#          14.370754  ,  358.15956409, -274.36584906,  -99.4642921 ,
#          -3.10730641,   30.55264256,   -6.43772933,    8.97654172,
#          64.60857065,   11.22384238,    4.71700918,   82.93485337])

# %%
train_test_score(test_model2)
# Out:
# Training_Score: 0.6707193084264795
# Testing_Score: 0.6833115740267505

# %%
import pickle

# %%
pickle.dump(test_model1, open('profit_predict_model.pkl', 'wb'))   # wb = write binary

# %% [markdown]
# #### Load the Model

# %%
loaded_model = pickle.load(open('profit_prediction_model.pkl', 'rb'))  # rb = read binary

# %%
prediction = loaded_model.predict(sample_df)
print(prediction)
# Out:
# [ -64.1218253    44.82613319  117.02980926   17.52773403  414.05656479
#    22.2267593   -86.1023033    -4.01473031   21.29572257  545.94376219
#  -421.96251913    3.86585725    8.10017565   26.00993249   10.71184995
#    16.17966182  268.03410927    4.98366129    7.34048309   67.99936181]

# %%
pickle.dump(scaler, open('Data_Scaling.pkl', 'wb'))   # wb = write binary

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load your data (replace this with your actual data loading code)
data = pd.read_csv('your_data.csv')

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder on the data
label_encoder.fit(data['category'])

# Get the dictionary of labels and their corresponding encoded values
label_dict = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# Display the dictionary
print(label_dict)
